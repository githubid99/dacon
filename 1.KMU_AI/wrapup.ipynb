# %% [markdown]
# 1. value 만 사용해서 corr 으로 pair 를 찾기 보다 hs4 code 같은 걸 사용해서 같이 feature 로 써서 pair 를 찾는다.
# 2. pair 를 찾을 때 여러가지 방법을 ensemble 느낌으로 섞어서 교집합을 최종 pair 로 찾을 수 있게 한다.

# %% [markdown]
# 앞으로 할 때 정할 양식
#
#
# - 시작하기 전에 어느정도 개략적인 전략을 설계한 이후에 시도를 한다.
# - 끝나면 wrap up 느낌으로 서로 idea 했던 거 공유하면서 잘한 점, 못한 점 정리해본다.
# - 매 version 별로 여기에 적용된 knob, idea 가 뭔지 그리고 결과가 어떻게 됐는지를 꼭 정리한다.
#   ipynb file 이면 code 맨 윗줄에 mark down 으로 해 놓으면 좋을 듯.
# -
