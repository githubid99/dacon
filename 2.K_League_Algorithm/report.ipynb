# %% [markdown]
# <style>
#     h2{
#         background-color: coral;
#         color: black;
#         border: solid; border-color: white;
#     }
# </style>
#
# <h2>Before Start</h2>
# <hr >
#
# <h4>Understanding Baseline</h4>
# <ul type="square">
#     <li>Data 이해: 각 Column 의미 파악, Shape, baseline 전처리 과정 이해</li>
#     <li>LSTM 이해: LSTM이 기본적으로 어떤 원리였었는지 DS2 필기랑 gpt 로 간략히 복습</li>
# </ul>
#
# <h4>초기 전략 세우기</h4>
# <ol>
#     <li>GPT 에게 전략 추천 받기</li>
#     <li>추천 사항 및 Baseline 기반으로 첫 시도해볼 전략 짜기</li>
#     <li>해당 전략 정리한 후 시도 및 결과 나오면 summary → 다시 2번의 전략 수립 시행</li>
# </ol>

# %% [markdown]
# <style>
#     h2{
#         background-color: coral;
#         color: black;
#         border: solid; border-color: white;
#     }
# </style>
#
# <h2>Trail Summary</h2>
# <hr >
#
# <ol>
#     <li>Baseline : LSTM</li>
#     <li>TBU</li>
# </ol>

# %% [markdown]
# <style>
#     h2{
#         background-color: coral;
#         color: black;
#         border: solid; border-color: white;
#     }
# </style>
#
# <h2>Wrap Up</h2>
# <hr >
#
# <h4>What I have learned from this</h4>
# <ul type="square">
#     <li>TBU</li>
# </ul>
